# %%
from scipy.optimize import fsolve

def equation(n):
    return n**n - 9

solution = fsolve(equation, 2.4)[0]
result = solution ** solution

print(f"n ≈ {solution}")
print(f"n^n = {result}")
# Out:
# n ≈ 2.4509539280155797
# n^n = 9.0
